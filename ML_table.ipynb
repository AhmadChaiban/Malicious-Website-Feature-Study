# %%
import pandas as pd 
import numpy as np
import sys
from tqdm import tqdm

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2

from xgboost import XGBClassifier

np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# ## Reading the Dataset

# %%
df_surtur = pd.read_csv('super_final_dataset_surtur.csv')
df_surtur.head()
# Out:
#                                              content  has_IP_in_url  \
# 0  <html><head><meta content="no-cache" http-equi...            0.0
# 1  �MQTH1TDa1��fl�hF1bVOFESLCnBbRI9MRTH1PDa1SP...            0.0
# 2  <!DOCTYPE html>\n<html data-adblockkey="MFwwDQ...            0.0
# 3  <html>\n<head>\n<meta content="noarchive" name...            0.0
# 4  <html><head><meta content="no-cache" http-equi...            0.0
#
#    having_@_in_url                         hostname  https  label  \
# 0              0.0  00.124.324.77.00.opteamevent.hu      0      1
# 1              0.0             00005ik.rcomhost.com      0      1
# 2              0.0             000098.ihostfull.com      0      1
# 3              0.0             000p6vl.wcomhost.com      0      1
# 4              0.0    001.002.003.23.opteamevent.hu      0      1
#
#    length_hostname  number_subdomains  number_underscores  \
# 0             31.0                6.0                 0.0
# 1             20.0                1.0                 0.0
# 2             20.0                1.0                 0.0
# 3             20.0                1.0                 0.0
# 4             29.0                5.0                 0.0
#
#    ratio_digits_hostname  ...  content_emb_12  content_emb_13 content_emb_14  \
# 0               0.387097  ...        0.045458        0.045459       0.045461
# 1               0.250000  ...        0.044160        0.044160       0.044160
# 2               0.300000  ...        0.046553        0.048641       0.048712
# 3               0.200000  ...        0.047654        0.047670       0.047664
# 4               0.379310  ...        0.045458        0.045459       0.045461
#
#    content_emb_15  content_emb_16 content_emb_17  content_emb_18  \
# 0        0.045461        0.045458       0.045458        0.045458
# 1        0.044160        0.044160       0.044160        0.044160
# 2        0.047349        0.048684       0.047914        0.048007
# 3        0.047662        0.047670       0.047674        0.047660
# 4        0.045461        0.045458       0.045458        0.045458
#
#    content_emb_19  is_in_alexa  num_?s
# 0        0.045460            0       0
# 1        0.044159            0       0
# 2        0.049129            0       0
# 3        0.047667            1       0
# 4        0.045460            0       0
#
# [5 rows x 116 columns]

# %%
print(np.array(df_surtur.columns))
# Out:
# ['content' 'has_IP_in_url' 'having_@_in_url' 'hostname' 'https' 'label'
#  'length_hostname' 'number_subdomains' 'number_underscores'
#  'ratio_digits_hostname' 'ratio_digits_url' 'tld' 'url' 'url_len' 'who_is'
#  'js' 'js_len' 'js_ref' 'js_array_len_avg' 'js_array_len_max'
#  'content_len' 'num_js_func_calls' 'malicious_func_count'
#  'total_url_count' 'ext_url_count' 'num_semicolons' 'num_zeros'
#  'num_spaces' 'num_hyphens' 'num_@s' 'num_queries' 'num_ampersands'
#  'num_equals' 'domain' 'domain_len' 'img_mean' 'img_mean_red'
#  'image_mobnet_0' 'image_mobnet_1' 'image_mobnet_2' 'image_mobnet_3'
#  'image_mobnet_4' 'image_mobnet_5' 'image_mobnet_6' 'image_mobnet_7'
#  'image_mobnet_8' 'image_mobnet_9' 'image_mobnet_10' 'image_mobnet_11'
#  'image_mobnet_12' 'image_mobnet_13' 'image_mobnet_14' 'image_mobnet_15'
#  'image_mobnet_16' 'image_mobnet_17' 'image_mobnet_18' 'image_mobnet_19'
#  'dcd_color_1' 'dcd_color_2' 'dcd_color_3' 'dcd_color_4' 'dcd_color_5'
#  'google_is_safe' 'ip_address' 'location' 'url_emb_mean'
#  'url_emb_mean_red' 'url_emb_0' 'url_emb_1' 'url_emb_2' 'url_emb_3'
#  'url_emb_4' 'url_emb_5' 'url_emb_6' 'url_emb_7' 'url_emb_8' 'url_emb_9'
#  'url_emb_10' 'url_emb_11' 'url_emb_12' 'url_emb_13' 'url_emb_14'
#  'url_emb_15' 'url_emb_16' 'url_emb_17' 'url_emb_18' 'url_emb_19'
#  'hex_len' 'has_hex' 'unique_url_chars' 'unique_url_nums'
#  'unique_url_letters' 'ratio_let_chars' 'ratio_nums_chars' 'content_emb_0'
#  'content_emb_1' 'content_emb_2' 'content_emb_3' 'content_emb_4'
#  'content_emb_5' 'content_emb_6' 'content_emb_7' 'content_emb_8'
#  'content_emb_9' 'content_emb_10' 'content_emb_11' 'content_emb_12'
#  'content_emb_13' 'content_emb_14' 'content_emb_15' 'content_emb_16'
#  'content_emb_17' 'content_emb_18' 'content_emb_19' 'is_in_alexa' 'num_?s']

# %% [markdown]
# ## Machine Learning

# %%
def make_classification(features_to_keep):
    X = df_surtur[features_to_keep]
    X = X.drop(columns = ['label', 'content', 'hostname', 'url', 'js', 
                          'domain', 'google_is_safe', 'ip_address'])
    y = df_surtur['label']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=20)
    
    xgboost_model = XGBClassifier(verbosity=0, 
                              max_depth=7,
                              min_child_weight=1,
                              n_estimators=165,
                              colsample_bylevel=1,
                              colsample_bytree=1, 
                              num_parallel_tree=1,
                              learning_rate=0.3,
                              tree_method='exact', 
                              booster='dart',
                              gamma=1e-10,
                              alpha=0,
                              scale_pos_weight= 1,  # 1.375520774687535,
                              subsample=1,
                              n_jobs=-1)

    xgboost_model.fit(X_train, y_train)
    
    y_pred = xgboost_model.predict(X_test)
    
    print(f'Accuracy_score = {accuracy_score(y_test, y_pred)}')
    print('\n')
    print(classification_report(y_test, y_pred, target_names=['benign', 'malicious'], digits=4))
    
    feat_imp = xgboost_model.feature_importances_
    feat_dict = {}

    for i in range(len(feat_imp)):
        feat_dict[X.columns[i]] = feat_imp[i]

    feat_dict = {k: v for k, v in sorted(feat_dict.items(), key=lambda item: item[1], reverse=True)}

    print("{:<25} {:<25}".format('Feature' ,'Importance'))
    for k, v in feat_dict.items():
        num = v
        print("{:<25} {:<25%}".format(k, num))

# %% [markdown]
# ### All Features without embeddings

# %%
baseline_feats = []
for feature in df_surtur.columns:
    if all(value not in feature for value in ['emb', 'mobnet', 'img_mean', 'url_emb_mean']):
        baseline_feats.append(feature)
        
make_classification(baseline_feats)
# Out:
# /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Accuracy_score = 0.8310740354535975
#
#
#               precision    recall  f1-score   support
#
#       benign     0.8182    0.9087    0.8611      6079
#    malicious     0.8539    0.7255    0.7845      4470
#
#     accuracy                         0.8311     10549
#    macro avg     0.8361    0.8171    0.8228     10549
# weighted avg     0.8333    0.8311    0.8286     10549
#
# Feature                   Importance
# who_is                    12.321550%
# unique_url_nums           8.626608%
# unique_url_chars          6.183530%
# https                     4.710356%
# tld                       4.121293%
# number_subdomains         3.091990%
# url_len                   3.065580%
# num_hyphens               2.782290%
# having_@_in_url           2.776576%
# is_in_alexa               2.729821%
# dcd_color_1               2.676867%
# location                  2.507020%
# content_len               2.445210%
# js_len                    2.424547%
# has_IP_in_url             2.188411%
# num_equals                2.073303%
# length_hostname           1.969011%
# ratio_digits_url          1.738843%
# number_underscores        1.734747%
# num_queries               1.728657%
# num_ampersands            1.720909%
# dcd_color_2               1.709365%
# js_array_len_max          1.708402%
# ratio_digits_hostname     1.695677%
# has_hex                   1.649200%
# malicious_func_count      1.638810%
# num_js_func_calls         1.551527%
# num_spaces                1.548706%
# js_array_len_avg          1.512580%
# ext_url_count             1.478664%
# dcd_color_5               1.426795%
# js_ref                    1.425786%
# total_url_count           1.227534%
# hex_len                   1.222870%
# domain_len                1.217134%
# num_semicolons            1.022290%
# unique_url_letters        0.968920%
# ratio_let_chars           0.808257%
# num_zeros                 0.782175%
# dcd_color_4               0.776426%
# dcd_color_3               0.736801%
# num_@s                    0.274961%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %% [markdown]
# ### Lexical Features

# %%
feats_to_drop = ['label', 'content', 'hostname', 'url', 'js', 
                    'domain', 'google_is_safe', 'ip_address']

# %%
lexical_features = ['has_IP_in_url', 'having_@_in_url', 'length_hostname', 'number_subdomains', 
                    'number_underscores', 'ratio_digits_hostname', 'ratio_digits_url', 'tld', 
                    'url_len', 'num_semicolons', 'num_zeros', 'num_spaces', 'num_hyphens', 
                    'num_@s', 'num_queries', 'num_ampersands', 'num_equals', 'domain_len',
                    'hex_len', 'has_hex', 'unique_url_chars', 'unique_url_nums', 'unique_url_letters',
                    'ratio_let_chars', 'ratio_nums_chars', 'num_?s']

make_classification(lexical_features + feats_to_drop)
# Out:
# Accuracy_score = 0.754763484690492
#
#
#               precision    recall  f1-score   support
#
#       benign     0.7482    0.8659    0.8027      6079
#    malicious     0.7680    0.6036    0.6759      4470
#
#     accuracy                         0.7548     10549
#    macro avg     0.7581    0.7348    0.7393     10549
# weighted avg     0.7566    0.7548    0.7490     10549
#
# Feature                   Importance
# unique_url_nums           12.100916%
# has_hex                   9.470193%
# unique_url_chars          9.390506%
# tld                       7.404562%
# having_@_in_url           6.221763%
# number_subdomains         5.808054%
# num_hyphens               4.286741%
# number_underscores        4.279814%
# num_equals                4.208982%
# num_queries               3.669810%
# url_len                   3.467369%
# num_ampersands            3.394108%
# length_hostname           3.364105%
# num_spaces                3.085423%
# domain_len                2.705688%
# ratio_digits_hostname     2.601112%
# has_IP_in_url             2.497648%
# hex_len                   2.246941%
# ratio_digits_url          2.069662%
# num_semicolons            1.834517%
# num_zeros                 1.682703%
# unique_url_letters        1.653658%
# ratio_let_chars           1.426497%
# num_@s                    1.129225%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %% [markdown]
# ### Host-based Features

# %%
host_feats = ['https', 'who_is', 'is_in_alexa', 'location']

make_classification(host_feats + feats_to_drop)
make_classification(lexical_features + host_feats + feats_to_drop)
# Out:
# Accuracy_score = 0.6570291022845768
#
#
#               precision    recall  f1-score   support
#
#       benign     0.6615    0.8289    0.7358      6079
#    malicious     0.6453    0.4233    0.5112      4470
#
#     accuracy                         0.6570     10549
#    macro avg     0.6534    0.6261    0.6235     10549
# weighted avg     0.6547    0.6570    0.6407     10549
#
# Feature                   Importance
# is_in_alexa               48.669788%
# location                  32.508582%
# https                     9.596092%
# who_is                    9.225541%
# Accuracy_score = 0.8002654280026543
#
#
#               precision    recall  f1-score   support
#
#       benign     0.7897    0.8906    0.8371      6079
#    malicious     0.8199    0.6774    0.7419      4470
#
#     accuracy                         0.8003     10549
#    macro avg     0.8048    0.7840    0.7895     10549
# weighted avg     0.8025    0.8003    0.7968     10549
#
# Feature                   Importance
# who_is                    12.683980%
# unique_url_nums           9.811046%
# location                  7.298791%
# unique_url_chars          6.797795%
# https                     5.114170%
# is_in_alexa               5.058545%
# tld                       4.994263%
# having_@_in_url           4.788756%
# number_subdomains         3.474522%
# has_hex                   3.287062%
# number_underscores        3.267392%
# num_equals                3.163332%
# num_queries               2.961843%
# num_hyphens               2.913482%
# url_len                   2.830929%
# length_hostname           2.594906%
# num_ampersands            2.458526%
# domain_len                2.073560%
# ratio_digits_hostname     1.939598%
# ratio_digits_url          1.784209%
# num_spaces                1.714880%
# hex_len                   1.656491%
# has_IP_in_url             1.534821%
# unique_url_letters        1.445610%
# num_semicolons            1.361052%
# num_@s                    1.010247%
# ratio_let_chars           0.992443%
# num_zeros                 0.987749%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %% [markdown]
# ### Content-based Features

# %%
content_feats = ['js_len', 'js_ref', 'js_array_len_avg', 'js_array_len_max',
                 'content_len', 'num_js_func_calls', 'malicious_func_count','total_url_count', 
                 'ext_url_count', 'dcd_color_1', 'dcd_color_2', 'dcd_color_3', 'dcd_color_4', 'dcd_color_5']

make_classification(content_feats + feats_to_drop)
make_classification(lexical_features + host_feats + feats_to_drop + content_feats)
# Out:
# Accuracy_score = 0.7630107119158214
#
#
#               precision    recall  f1-score   support
#
#       benign     0.7628    0.8544    0.8060      6079
#    malicious     0.7634    0.6387    0.6955      4470
#
#     accuracy                         0.7630     10549
#    macro avg     0.7631    0.7466    0.7508     10549
# weighted avg     0.7630    0.7630    0.7592     10549
#
# Feature                   Importance
# js_array_len_avg          11.331429%
# dcd_color_2               10.857553%
# js_len                    8.827004%
# dcd_color_1               8.539956%
# content_len               7.607314%
# num_js_func_calls         6.972174%
# js_array_len_max          6.771773%
# malicious_func_count      6.755401%
# ext_url_count             6.497730%
# total_url_count           6.315522%
# js_ref                    6.143576%
# dcd_color_5               4.894791%
# dcd_color_3               4.314781%
# dcd_color_4               4.170984%
# Accuracy_score = 0.8310740354535975
#
#
#               precision    recall  f1-score   support
#
#       benign     0.8182    0.9087    0.8611      6079
#    malicious     0.8539    0.7255    0.7845      4470
#
#     accuracy                         0.8311     10549
#    macro avg     0.8361    0.8171    0.8228     10549
# weighted avg     0.8333    0.8311    0.8286     10549
#
# Feature                   Importance
# who_is                    12.321222%
# unique_url_nums           8.626378%
# unique_url_chars          6.183365%
# https                     4.710231%
# tld                       4.121184%
# number_subdomains         3.091908%
# url_len                   3.065499%
# num_hyphens               2.782216%
# having_@_in_url           2.776502%
# is_in_alexa               2.729748%
# dcd_color_1               2.676796%
# location                  2.506953%
# content_len               2.450153%
# js_len                    2.424483%
# has_IP_in_url             2.188353%
# num_equals                2.073248%
# length_hostname           1.968958%
# ratio_digits_url          1.738797%
# number_underscores        1.734701%
# num_queries               1.728611%
# num_ampersands            1.720864%
# dcd_color_2               1.709319%
# js_array_len_max          1.708356%
# ratio_digits_hostname     1.695632%
# has_hex                   1.649156%
# malicious_func_count      1.638767%
# num_js_func_calls         1.551486%
# num_spaces                1.548665%
# js_array_len_avg          1.512540%
# ext_url_count             1.478625%
# js_ref                    1.430135%
# dcd_color_5               1.426757%
# total_url_count           1.227502%
# hex_len                   1.218929%
# domain_len                1.214271%
# num_semicolons            1.022263%
# unique_url_letters        0.968894%
# ratio_let_chars           0.808236%
# num_zeros                 0.782155%
# dcd_color_4               0.776406%
# dcd_color_3               0.736781%
# num_@s                    0.274954%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %% [markdown]
# ### URL Embeddings from the longformer
#
# https://huggingface.co/transformers/model_doc/longformer.html

# %%
url_emb_feats = ['url_emb_mean', 'url_emb_mean_red', 'url_emb_0', 
                 'url_emb_1', 'url_emb_2', 'url_emb_3', 'url_emb_4', 
                 'url_emb_5', 'url_emb_6', 'url_emb_7', 'url_emb_8', 
                 'url_emb_9', 'url_emb_10', 'url_emb_11', 'url_emb_12', 
                 'url_emb_13', 'url_emb_14', 'url_emb_15', 'url_emb_16', 
                 'url_emb_17', 'url_emb_18', 'url_emb_19']

make_classification(url_emb_feats + feats_to_drop)
make_classification(url_emb_feats + feats_to_drop + lexical_features + host_feats + content_feats)
# Out:
# Accuracy_score = 0.7643378519290928
#
#
#               precision    recall  f1-score   support
#
#       benign     0.7532    0.8791    0.8113      6079
#    malicious     0.7872    0.6083    0.6863      4470
#
#     accuracy                         0.7643     10549
#    macro avg     0.7702    0.7437    0.7488     10549
# weighted avg     0.7676    0.7643    0.7583     10549
#
# Feature                   Importance
# url_emb_mean_red          19.876653%
# url_emb_1                 18.713418%
# url_emb_mean              9.050211%
# url_emb_3                 3.517240%
# url_emb_8                 3.114260%
# url_emb_7                 3.106756%
# url_emb_4                 3.079773%
# url_emb_5                 3.053969%
# url_emb_2                 3.037693%
# url_emb_10                2.862465%
# url_emb_14                2.859021%
# url_emb_13                2.808229%
# url_emb_11                2.765269%
# url_emb_18                2.752889%
# url_emb_6                 2.738562%
# url_emb_12                2.695907%
# url_emb_0                 2.549071%
# url_emb_9                 2.469416%
# url_emb_16                2.365509%
# url_emb_19                2.268307%
# url_emb_15                2.177299%
# url_emb_17                2.138087%
# Accuracy_score = 0.8328751540430372
#
#
#               precision    recall  f1-score   support
#
#       benign     0.8217    0.9067    0.8621      6079
#    malicious     0.8524    0.7324    0.7879      4470
#
#     accuracy                         0.8329     10549
#    macro avg     0.8370    0.8196    0.8250     10549
# weighted avg     0.8347    0.8329    0.8307     10549
#
# Feature                   Importance
# url_emb_1                 7.886606%
# url_emb_mean_red          7.101863%
# url_emb_mean              4.707672%
# who_is                    3.811943%
# is_in_alexa               3.298764%
# unique_url_nums           3.251656%
# num_equals                3.082216%
# num_hyphens               3.035547%
# location                  2.976338%
# tld                       2.839136%
# js_len                    2.556987%
# number_underscores        2.425886%
# num_ampersands            2.416476%
# content_len               2.363503%
# number_subdomains         2.202781%
# has_hex                   1.971466%
# url_len                   1.825184%
# dcd_color_1               1.792858%
# num_js_func_calls         1.788363%
# https                     1.698920%
# ratio_digits_url          1.551889%
# total_url_count           1.534880%
# unique_url_chars          1.461440%
# js_array_len_avg          1.437679%
# length_hostname           1.331150%
# having_@_in_url           1.189527%
# ext_url_count             1.154512%
# hex_len                   1.147856%
# num_queries               1.144210%
# malicious_func_count      1.138546%
# dcd_color_5               1.138074%
# ratio_digits_hostname     1.073290%
# dcd_color_2               1.071290%
# url_emb_3                 1.069743%
# js_ref                    1.044635%
# num_spaces                1.025311%
# js_array_len_max          1.025068%
# domain_len                0.944584%
# url_emb_2                 0.887177%
# has_IP_in_url             0.825498%
# url_emb_7                 0.813342%
# unique_url_letters        0.758162%
# num_semicolons            0.718332%
# url_emb_5                 0.702893%
# url_emb_6                 0.657414%
# dcd_color_4               0.652753%
# ratio_let_chars           0.649252%
# url_emb_4                 0.646040%
# url_emb_8                 0.644450%
# url_emb_14                0.628036%
# url_emb_0                 0.613920%
# url_emb_13                0.605271%
# dcd_color_3               0.596642%
# url_emb_18                0.564895%
# url_emb_12                0.554833%
# url_emb_16                0.541925%
# url_emb_9                 0.541321%
# url_emb_17                0.534066%
# url_emb_11                0.520075%
# url_emb_10                0.513274%
# url_emb_15                0.457823%
# url_emb_19                0.438745%
# num_zeros                 0.416017%
# num_@s                    0.000000%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %% [markdown]
# ### Image Embeddings

# %%
img_mobnet_embeddings = ['img_mean', 'img_mean_red', 'image_mobnet_0', 
                         'image_mobnet_1', 'image_mobnet_2', 'image_mobnet_3', 
                         'image_mobnet_4', 'image_mobnet_5', 'image_mobnet_6', 'image_mobnet_7', 
                         'image_mobnet_8', 'image_mobnet_9', 'image_mobnet_10', 'image_mobnet_11', 
                         'image_mobnet_12', 'image_mobnet_13', 'image_mobnet_14', 'image_mobnet_15',
                         'image_mobnet_16', 'image_mobnet_17', 'image_mobnet_18', 'image_mobnet_19']

make_classification(img_mobnet_embeddings + feats_to_drop)
make_classification(url_emb_feats + feats_to_drop + lexical_features + host_feats
                    + content_feats + img_mobnet_embeddings)
# Out:
# Accuracy_score = 0.6128542989856859
#
#
#               precision    recall  f1-score   support
#
#       benign     0.6194    0.8510    0.7170      6079
#    malicious     0.5878    0.2890    0.3875      4470
#
#     accuracy                         0.6129     10549
#    macro avg     0.6036    0.5700    0.5523     10549
# weighted avg     0.6060    0.6129    0.5774     10549
#
# Feature                   Importance
# img_mean_red              15.427394%
# img_mean                  12.161608%
# image_mobnet_17           4.936055%
# image_mobnet_14           3.774932%
# image_mobnet_10           3.752293%
# image_mobnet_15           3.655128%
# image_mobnet_16           3.629029%
# image_mobnet_11           3.626671%
# image_mobnet_8            3.581095%
# image_mobnet_3            3.567450%
# image_mobnet_19           3.534382%
# image_mobnet_12           3.526892%
# image_mobnet_9            3.522901%
# image_mobnet_6            3.511529%
# image_mobnet_0            3.503765%
# image_mobnet_18           3.502332%
# image_mobnet_1            3.492707%
# image_mobnet_13           3.477367%
# image_mobnet_7            3.473540%
# image_mobnet_5            3.470851%
# image_mobnet_2            3.439786%
# image_mobnet_4            3.432295%
# Accuracy_score = 0.8357190255000474
#
#
#               precision    recall  f1-score   support
#
#       benign     0.8227    0.9113    0.8647      6079
#    malicious     0.8587    0.7329    0.7908      4470
#
#     accuracy                         0.8357     10549
#    macro avg     0.8407    0.8221    0.8278     10549
# weighted avg     0.8380    0.8357    0.8334     10549
#
# Feature                   Importance
# url_emb_1                 7.299935%
# url_emb_mean_red          6.284873%
# url_emb_mean              4.817472%
# num_hyphens               3.370524%
# num_ampersands            2.947600%
# who_is                    2.895937%
# number_underscores        2.739918%
# num_equals                2.426511%
# tld                       2.411445%
# js_len                    2.301983%
# image_mobnet_3            2.127814%
# is_in_alexa               2.046808%
# number_subdomains         2.023768%
# location                  1.923975%
# has_hex                   1.900660%
# content_len               1.838458%
# unique_url_nums           1.811775%
# https                     1.654717%
# total_url_count           1.648203%
# ratio_digits_url          1.548928%
# num_js_func_calls         1.537451%
# url_len                   1.463505%
# js_array_len_avg          1.458095%
# dcd_color_5               1.445518%
# hex_len                   1.175398%
# length_hostname           1.108164%
# unique_url_chars          1.101130%
# ratio_digits_hostname     1.056132%
# url_emb_3                 1.032516%
# dcd_color_2               1.024913%
# having_@_in_url           1.016263%
# malicious_func_count      0.926519%
# ext_url_count             0.879234%
# img_mean                  0.846004%
# js_ref                    0.836543%
# domain_len                0.826171%
# dcd_color_1               0.809823%
# url_emb_7                 0.798920%
# ratio_let_chars           0.768697%
# js_array_len_max          0.749950%
# num_queries               0.741703%
# num_spaces                0.708679%
# url_emb_2                 0.703984%
# unique_url_letters        0.671345%
# dcd_color_4               0.667463%
# has_IP_in_url             0.667021%
# url_emb_8                 0.660500%
# dcd_color_3               0.656439%
# url_emb_6                 0.603665%
# url_emb_13                0.577502%
# url_emb_11                0.571557%
# url_emb_10                0.560804%
# url_emb_0                 0.556513%
# url_emb_5                 0.554790%
# url_emb_4                 0.554219%
# url_emb_19                0.523393%
# url_emb_12                0.516939%
# image_mobnet_17           0.514262%
# image_mobnet_6            0.514188%
# image_mobnet_19           0.508338%
# url_emb_15                0.505168%
# url_emb_9                 0.502556%
# img_mean_red              0.500388%
# url_emb_16                0.476968%
# url_emb_18                0.476283%
# image_mobnet_9            0.464718%
# image_mobnet_13           0.451081%
# num_zeros                 0.450287%
# image_mobnet_5            0.449977%
# image_mobnet_1            0.449350%
# image_mobnet_14           0.448135%
# url_emb_14                0.444732%
# image_mobnet_11           0.431581%
# image_mobnet_4            0.428292%
# url_emb_17                0.427984%
# image_mobnet_8            0.424130%
# image_mobnet_2            0.423407%
# image_mobnet_0            0.420448%
# image_mobnet_15           0.417633%
# image_mobnet_10           0.417039%
# image_mobnet_18           0.414433%
# image_mobnet_7            0.413643%
# image_mobnet_16           0.404264%
# image_mobnet_12           0.400541%
# num_@s                    0.276434%
# num_semicolons            0.164974%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %% [markdown]
# ## Content Embeddings

# %%
content_embeddings = ['content_emb_0', 'content_emb_1', 'content_emb_2', 
                      'content_emb_3', 'content_emb_4', 'content_emb_5', 
                      'content_emb_6', 'content_emb_7', 'content_emb_8', 
                      'content_emb_9', 'content_emb_10', 'content_emb_11', 
                      'content_emb_12', 'content_emb_13', 'content_emb_14', 
                      'content_emb_15', 'content_emb_16', 'content_emb_17', 
                      'content_emb_18', 'content_emb_19']

make_classification(content_embeddings + feats_to_drop)
make_classification(url_emb_feats + feats_to_drop + lexical_features + host_feats
                    + content_feats + img_mobnet_embeddings + content_embeddings)
# Out:
# Accuracy_score = 0.6656555123708409
#
#
#               precision    recall  f1-score   support
#
#       benign     0.6535    0.8937    0.7550      6079
#    malicious     0.7110    0.3555    0.4740      4470
#
#     accuracy                         0.6657     10549
#    macro avg     0.6822    0.6246    0.6145     10549
# weighted avg     0.6778    0.6657    0.6359     10549
#
# Feature                   Importance
# content_emb_19            13.811943%
# content_emb_2             7.238602%
# content_emb_13            5.884395%
# content_emb_12            5.725258%
# content_emb_10            5.571158%
# content_emb_0             4.946371%
# content_emb_18            4.665475%
# content_emb_3             4.563457%
# content_emb_6             4.528358%
# content_emb_8             4.362756%
# content_emb_9             4.191156%
# content_emb_14            4.169448%
# content_emb_5             4.120385%
# content_emb_11            3.927967%
# content_emb_17            3.910561%
# content_emb_1             3.822533%
# content_emb_4             3.722696%
# content_emb_7             3.667419%
# content_emb_16            3.635702%
# content_emb_15            3.534368%
# Accuracy_score = 0.8328751540430372
#
#
#               precision    recall  f1-score   support
#
#       benign     0.8189    0.9115    0.8627      6079
#    malicious     0.8578    0.7260    0.7864      4470
#
#     accuracy                         0.8329     10549
#    macro avg     0.8384    0.8187    0.8246     10549
# weighted avg     0.8354    0.8329    0.8304     10549
#
# Feature                   Importance
# url_emb_1                 7.205471%
# url_emb_mean_red          6.423721%
# url_emb_mean              4.508884%
# unique_url_nums           2.677328%
# num_hyphens               2.675291%
# num_equals                2.314571%
# num_ampersands            2.212725%
# who_is                    2.187404%
# js_len                    2.155840%
# tld                       2.077061%
# is_in_alexa               2.032159%
# number_underscores        1.954780%
# image_mobnet_3            1.817494%
# content_len               1.810339%
# number_subdomains         1.701711%
# location                  1.686198%
# https                     1.553002%
# num_js_func_calls         1.483862%
# has_hex                   1.462149%
# url_len                   1.434311%
# total_url_count           1.325198%
# dcd_color_5               1.291657%
# js_array_len_avg          1.261819%
# ratio_digits_url          1.153596%
# ratio_digits_hostname     1.105299%
# unique_url_chars          1.066132%
# hex_len                   1.046083%
# dcd_color_2               1.043412%
# length_hostname           0.993689%
# url_emb_3                 0.950341%
# malicious_func_count      0.874657%
# num_queries               0.826705%
# content_emb_2             0.817898%
# num_spaces                0.795392%
# js_ref                    0.783349%
# img_mean                  0.768327%
# having_@_in_url           0.760848%
# content_emb_8             0.703390%
# url_emb_7                 0.701210%
# dcd_color_1               0.690960%
# content_emb_0             0.676088%
# domain_len                0.669531%
# num_semicolons            0.661929%
# unique_url_letters        0.644385%
# content_emb_19            0.633945%
# url_emb_2                 0.633292%
# js_array_len_max          0.630467%
# ext_url_count             0.628155%
# ratio_let_chars           0.622486%
# dcd_color_4               0.614658%
# content_emb_13            0.613263%
# url_emb_8                 0.581428%
# url_emb_6                 0.571543%
# dcd_color_3               0.547413%
# content_emb_17            0.514211%
# url_emb_10                0.513208%
# content_emb_5             0.510794%
# url_emb_5                 0.508981%
# url_emb_4                 0.504516%
# content_emb_4             0.495070%
# image_mobnet_17           0.491472%
# content_emb_9             0.484125%
# url_emb_0                 0.483810%
# content_emb_10            0.482431%
# content_emb_6             0.481189%
# url_emb_13                0.474282%
# content_emb_18            0.473813%
# content_emb_3             0.455130%
# content_emb_11            0.443966%
# image_mobnet_6            0.443646%
# content_emb_16            0.431221%
# content_emb_14            0.417658%
# img_mean_red              0.416450%
# content_emb_1             0.415040%
# url_emb_19                0.410803%
# url_emb_12                0.405958%
# content_emb_7             0.405529%
# content_emb_15            0.404736%
# url_emb_9                 0.398218%
# image_mobnet_8            0.398208%
# content_emb_12            0.394596%
# image_mobnet_19           0.394106%
# image_mobnet_0            0.387707%
# image_mobnet_13           0.385506%
# image_mobnet_7            0.382678%
# url_emb_14                0.382391%
# image_mobnet_18           0.378835%
# image_mobnet_11           0.378334%
# image_mobnet_1            0.375053%
# image_mobnet_10           0.372140%
# image_mobnet_2            0.371890%
# image_mobnet_12           0.369408%
# image_mobnet_5            0.367286%
# image_mobnet_14           0.365074%
# image_mobnet_15           0.364974%
# url_emb_11                0.362913%
# url_emb_16                0.362228%
# image_mobnet_9            0.354349%
# image_mobnet_16           0.351125%
# image_mobnet_4            0.345887%
# url_emb_18                0.336273%
# num_zeros                 0.327085%
# url_emb_17                0.324619%
# url_emb_15                0.324564%
# has_IP_in_url             0.313663%
# num_@s                    0.000000%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %% [markdown]
# ### DCD

# %%
dcd_feats = ['dcd_color_1', 'dcd_color_2', 'dcd_color_3', 'dcd_color_4', 'dcd_color_5']

make_classification(dcd_feats + feats_to_drop)
# Out:
# Accuracy_score = 0.6938098397952412
#
#
#               precision    recall  f1-score   support
#
#       benign     0.7031    0.8112    0.7533      6079
#    malicious     0.6753    0.5342    0.5966      4470
#
#     accuracy                         0.6938     10549
#    macro avg     0.6892    0.6727    0.6749     10549
# weighted avg     0.6913    0.6938    0.6869     10549
#
# Feature                   Importance
# dcd_color_2               29.230213%
# dcd_color_1               25.545219%
# dcd_color_3               15.549251%
# dcd_color_5               14.965314%
# dcd_color_4               14.710005%

# %% [markdown]
# ### Best scores

# %%
make_classification(feats_to_drop + lexical_features + host_feats
                    + content_feats + ['img_mean', 'img_mean_red', 'image_mobnet_9']
                    + ['url_emb_mean', 'url_emb_mean_red', 'url_emb_1'])
# Out:
# Accuracy_score = 0.8398900369703289
#
#
#               precision    recall  f1-score   support
#
#       benign     0.8237    0.9187    0.8687      6079
#    malicious     0.8689    0.7327    0.7950      4470
#
#     accuracy                         0.8399     10549
#    macro avg     0.8463    0.8257    0.8318     10549
# weighted avg     0.8429    0.8399    0.8374     10549
#
# Feature                   Importance
# url_emb_1                 7.933941%
# url_emb_mean_red          6.343190%
# unique_url_nums           5.074929%
# who_is                    4.967113%
# url_emb_mean              3.353893%
# num_hyphens               3.353597%
# num_equals                3.083605%
# js_len                    2.952749%
# tld                       2.948724%
# is_in_alexa               2.921225%
# num_ampersands            2.652247%
# number_subdomains         2.609134%
# location                  2.524890%
# has_hex                   2.367930%
# https                     2.353659%
# number_underscores        2.324510%
# content_len               2.201165%
# img_mean                  2.097190%
# num_js_func_calls         2.092515%
# num_queries               1.937134%
# url_len                   1.892360%
# malicious_func_count      1.760763%
# total_url_count           1.752821%
# dcd_color_5               1.738572%
# length_hostname           1.720591%
# unique_url_chars          1.688375%
# having_@_in_url           1.645205%
# ratio_digits_url          1.579257%
# hex_len                   1.393632%
# ext_url_count             1.388671%
# js_array_len_avg          1.275734%
# js_array_len_max          1.270869%
# domain_len                1.257383%
# js_ref                    1.211358%
# dcd_color_2               1.118203%
# ratio_digits_hostname     1.117591%
# dcd_color_1               1.084416%
# ratio_let_chars           1.036510%
# num_spaces                1.021947%
# unique_url_letters        0.941865%
# dcd_color_4               0.919942%
# has_IP_in_url             0.831860%
# dcd_color_3               0.799856%
# num_zeros                 0.769503%
# image_mobnet_9            0.740536%
# num_@s                    0.726052%
# img_mean_red              0.653222%
# num_semicolons            0.569568%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %% [markdown]
# ## Additional embeddings from BERT

# %%
url_features = pd.read_csv('url_feats_sliding_window.csv')

scaler = MinMaxScaler()
url_features_scaled = scaler.fit_transform(url_features)

url_features_mean = url_features_scaled.mean(axis=1)

url_feat_new = SelectKBest(chi2, k=20).fit_transform(url_features_scaled, df_surtur['label'])
url_feat_new = pd.DataFrame(url_feat_new)

feat_array = []
for i in tqdm(range(len(url_feat_new.columns))):
     feat_array.append(f'url_emb_{i+20}')
        
url_feat_new.columns = feat_array
url_feat_new.head()

df_surtur['url_emb_mean_bert'] = url_features_mean
df_surtur['url_emb_mean_red_bert'] = url_feat_new.mean(axis=1).values

df_surtur = pd.concat([df_surtur, url_feat_new], axis=1)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 144134.16it/s]

# %%
url_emb_feats_bert = ['url_emb_mean_bert', 'url_emb_mean_red_bert', 'url_emb_20', 
                     'url_emb_21', 'url_emb_22', 'url_emb_23', 'url_emb_24', 
                     'url_emb_25', 'url_emb_26', 'url_emb_27', 'url_emb_28', 
                     'url_emb_29', 'url_emb_30', 'url_emb_31', 'url_emb_32', 
                     'url_emb_33', 'url_emb_34', 'url_emb_35', 'url_emb_36', 
                     'url_emb_37', 'url_emb_38', 'url_emb_39']


make_classification(url_emb_feats_bert + feats_to_drop)
make_classification(url_emb_feats + feats_to_drop + lexical_features + host_feats
                    + content_feats + img_mobnet_embeddings + content_embeddings + url_emb_feats_bert)
# Out:
# Accuracy_score = 0.7511612475116125
#
#
#               precision    recall  f1-score   support
#
#       benign     0.7529    0.8457    0.7966      6079
#    malicious     0.7479    0.6226    0.6795      4470
#
#     accuracy                         0.7512     10549
#    macro avg     0.7504    0.7341    0.7381     10549
# weighted avg     0.7508    0.7512    0.7470     10549
#
# Feature                   Importance
# url_emb_20                19.957052%
# url_emb_29                12.471469%
# url_emb_mean_red_bert     6.176529%
# url_emb_mean_bert         5.323802%
# url_emb_24                4.307182%
# url_emb_34                4.020206%
# url_emb_33                3.940124%
# url_emb_21                3.879892%
# url_emb_27                3.556989%
# url_emb_35                3.455467%
# url_emb_22                3.353843%
# url_emb_23                3.302867%
# url_emb_28                3.026952%
# url_emb_37                3.014336%
# url_emb_32                2.863790%
# url_emb_30                2.674517%
# url_emb_26                2.563785%
# url_emb_31                2.539542%
# url_emb_38                2.525008%
# url_emb_25                2.439890%
# url_emb_36                2.318471%
# url_emb_39                2.288293%
# Accuracy_score = 0.8356242297848138
#
#
#               precision    recall  f1-score   support
#
#       benign     0.8251    0.9071    0.8641      6079
#    malicious     0.8539    0.7385    0.7920      4470
#
#     accuracy                         0.8356     10549
#    macro avg     0.8395    0.8228    0.8281     10549
# weighted avg     0.8373    0.8356    0.8336     10549
#
# Feature                   Importance
# url_emb_mean_red          6.639564%
# url_emb_20                4.335718%
# url_emb_1                 4.280211%
# num_ampersands            3.983479%
# url_emb_mean_bert         3.695726%
# url_emb_mean              2.553452%
# has_hex                   2.140078%
# is_in_alexa               1.929615%
# js_len                    1.831843%
# https                     1.728293%
# unique_url_nums           1.687717%
# tld                       1.686078%
# num_hyphens               1.595645%
# content_len               1.561676%
# location                  1.519693%
# image_mobnet_3            1.502668%
# number_subdomains         1.235191%
# url_emb_24                1.193674%
# num_js_func_calls         1.178988%
# url_emb_33                1.149284%
# number_underscores        1.081688%
# dcd_color_2               1.037989%
# img_mean_red              1.035583%
# ratio_digits_url          1.022740%
# url_emb_mean_red_bert     0.983375%
# ext_url_count             0.973533%
# total_url_count           0.959579%
# url_emb_34                0.922898%
# num_equals                0.892728%
# domain_len                0.883557%
# num_queries               0.837841%
# hex_len                   0.825117%
# url_emb_23                0.811216%
# url_len                   0.803624%
# unique_url_chars          0.780661%
# js_array_len_avg          0.779106%
# url_emb_22                0.767265%
# dcd_color_5               0.762728%
# url_emb_29                0.730927%
# who_is                    0.681851%
# url_emb_21                0.675385%
# having_@_in_url           0.674582%
# length_hostname           0.626282%
# js_ref                    0.618774%
# dcd_color_1               0.598179%
# ratio_digits_hostname     0.595149%
# content_emb_2             0.593488%
# image_mobnet_14           0.591982%
# num_semicolons            0.571577%
# malicious_func_count      0.568923%
# ratio_let_chars           0.551086%
# has_IP_in_url             0.543294%
# num_spaces                0.534220%
# url_emb_7                 0.524764%
# url_emb_35                0.522417%
# url_emb_3                 0.514156%
# content_emb_8             0.506831%
# content_emb_7             0.498785%
# content_emb_0             0.497966%
# url_emb_37                0.496879%
# dcd_color_4               0.493258%
# content_emb_9             0.480579%
# url_emb_2                 0.469642%
# url_emb_27                0.465492%
# img_mean                  0.455373%
# content_emb_3             0.451486%
# js_array_len_max          0.445680%
# content_emb_13            0.443494%
# content_emb_1             0.443255%
# url_emb_30                0.441778%
# url_emb_32                0.434526%
# url_emb_4                 0.429715%
# num_zeros                 0.422665%
# url_emb_6                 0.421782%
# image_mobnet_17           0.421205%
# unique_url_letters        0.410660%
# url_emb_5                 0.406861%
# content_emb_4             0.406400%
# dcd_color_3               0.390291%
# content_emb_6             0.385682%
# url_emb_25                0.385641%
# content_emb_5             0.385511%
# url_emb_31                0.382911%
# content_emb_10            0.380610%
# content_emb_18            0.374612%
# content_emb_17            0.370193%
# url_emb_26                0.368600%
# content_emb_16            0.364277%
# url_emb_28                0.362637%
# url_emb_0                 0.357421%
# content_emb_19            0.354516%
# url_emb_10                0.346851%
# url_emb_8                 0.343767%
# content_emb_14            0.342791%
# url_emb_18                0.340743%
# url_emb_14                0.336366%
# url_emb_36                0.330913%
# url_emb_12                0.325673%
# url_emb_13                0.322888%
# url_emb_9                 0.322290%
# content_emb_15            0.316445%
# content_emb_12            0.313796%
# url_emb_38                0.310606%
# image_mobnet_12           0.308899%
# image_mobnet_5            0.308149%
# url_emb_19                0.294114%
# image_mobnet_1            0.292751%
# url_emb_17                0.291227%
# image_mobnet_18           0.290434%
# image_mobnet_9            0.288175%
# image_mobnet_0            0.287631%
# image_mobnet_7            0.286261%
# url_emb_16                0.286013%
# image_mobnet_11           0.284967%
# content_emb_11            0.282812%
# image_mobnet_6            0.280464%
# image_mobnet_10           0.277934%
# url_emb_15                0.274997%
# url_emb_39                0.272760%
# image_mobnet_19           0.268632%
# image_mobnet_13           0.265151%
# image_mobnet_8            0.264755%
# image_mobnet_16           0.263187%
# image_mobnet_15           0.262825%
# image_mobnet_4            0.261793%
# image_mobnet_2            0.259023%
# url_emb_11                0.258876%
# num_@s                    0.220970%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %% [markdown]
# ## Best Score again

# %%
make_classification(feats_to_drop + lexical_features + host_feats
                    + content_feats + ['img_mean', 'img_mean_red', 'image_mobnet_9']
                    + ['url_emb_mean', 'url_emb_mean_red', 'url_emb_1', 
                       'url_emb_mean_bert', 'url_emb_mean_red_bert', 'url_emb_20'])
# Out:
# Accuracy_score = 0.8427339084273391
#
#
#               precision    recall  f1-score   support
#
#       benign     0.8290    0.9161    0.8704      6079
#    malicious     0.8669    0.7430    0.8001      4470
#
#     accuracy                         0.8427     10549
#    macro avg     0.8479    0.8295    0.8353     10549
# weighted avg     0.8450    0.8427    0.8406     10549
#
# Feature                   Importance
# url_emb_20                5.510643%
# url_emb_mean_red          5.413893%
# url_emb_1                 5.160495%
# num_ampersands            5.007708%
# https                     4.076918%
# url_emb_mean_bert         3.796947%
# is_in_alexa               3.084218%
# who_is                    2.945010%
# tld                       2.922234%
# number_subdomains         2.876776%
# js_len                    2.760551%
# location                  2.521563%
# has_hex                   2.473724%
# url_emb_mean              2.383096%
# num_hyphens               2.364780%
# num_equals                2.321772%
# content_len               1.995491%
# num_js_func_calls         1.821548%
# js_array_len_avg          1.783849%
# unique_url_nums           1.763970%
# number_underscores        1.668942%
# ratio_digits_url          1.661088%
# having_@_in_url           1.652095%
# img_mean                  1.551119%
# hex_len                   1.528176%
# url_len                   1.485793%
# num_semicolons            1.454739%
# total_url_count           1.425703%
# url_emb_mean_red_bert     1.415881%
# unique_url_chars          1.402911%
# num_queries               1.394502%
# dcd_color_2               1.386601%
# ext_url_count             1.381971%
# has_IP_in_url             1.366092%
# domain_len                1.318055%
# malicious_func_count      1.229958%
# js_ref                    1.202780%
# length_hostname           1.175869%
# img_mean_red              1.136755%
# num_zeros                 1.112011%
# dcd_color_5               1.111641%
# ratio_digits_hostname     1.083299%
# js_array_len_max          0.973959%
# dcd_color_1               0.937073%
# unique_url_letters        0.849020%
# dcd_color_4               0.847479%
# ratio_let_chars           0.840075%
# dcd_color_3               0.827985%
# image_mobnet_9            0.818745%
# num_spaces                0.774485%
# num_@s                    0.000000%
# ratio_nums_chars          0.000000%
# num_?s                    0.000000%

# %%
df_surtur.to_csv('final_dataset_both_embeddings.csv', index=False)

# %%
np.array(df_surtur.columns)
# Out:
# array(['content', 'has_IP_in_url', 'having_@_in_url', 'hostname', 'https',
#        'label', 'length_hostname', 'number_subdomains',
#        'number_underscores', 'ratio_digits_hostname', 'ratio_digits_url',
#        'tld', 'url', 'url_len', 'who_is', 'js', 'js_len', 'js_ref',
#        'js_array_len_avg', 'js_array_len_max', 'content_len',
#        'num_js_func_calls', 'malicious_func_count', 'total_url_count',
#        'ext_url_count', 'num_semicolons', 'num_zeros', 'num_spaces',
#        'num_hyphens', 'num_@s', 'num_queries', 'num_ampersands',
#        'num_equals', 'domain', 'domain_len', 'img_mean', 'img_mean_red',
#        'image_mobnet_0', 'image_mobnet_1', 'image_mobnet_2',
#        'image_mobnet_3', 'image_mobnet_4', 'image_mobnet_5',
#        'image_mobnet_6', 'image_mobnet_7', 'image_mobnet_8',
#        'image_mobnet_9', 'image_mobnet_10', 'image_mobnet_11',
#        'image_mobnet_12', 'image_mobnet_13', 'image_mobnet_14',
#        'image_mobnet_15', 'image_mobnet_16', 'image_mobnet_17',
#        'image_mobnet_18', 'image_mobnet_19', 'dcd_color_1', 'dcd_color_2',
#        'dcd_color_3', 'dcd_color_4', 'dcd_color_5', 'google_is_safe',
#        'ip_address', 'location', 'url_emb_mean', 'url_emb_mean_red',
#        'url_emb_0', 'url_emb_1', 'url_emb_2', 'url_emb_3', 'url_emb_4',
#        'url_emb_5', 'url_emb_6', 'url_emb_7', 'url_emb_8', 'url_emb_9',
#        'url_emb_10', 'url_emb_11', 'url_emb_12', 'url_emb_13',
#        'url_emb_14', 'url_emb_15', 'url_emb_16', 'url_emb_17',
#        'url_emb_18', 'url_emb_19', 'hex_len', 'has_hex',
#        'unique_url_chars', 'unique_url_nums', 'unique_url_letters',
#        'ratio_let_chars', 'ratio_nums_chars', 'content_emb_0',
#        'content_emb_1', 'content_emb_2', 'content_emb_3', 'content_emb_4',
#        'content_emb_5', 'content_emb_6', 'content_emb_7', 'content_emb_8',
#        'content_emb_9', 'content_emb_10', 'content_emb_11',
#        'content_emb_12', 'content_emb_13', 'content_emb_14',
#        'content_emb_15', 'content_emb_16', 'content_emb_17',
#        'content_emb_18', 'content_emb_19', 'is_in_alexa', 'num_?s',
#        'url_emb_mean_bert', 'url_emb_mean_red_bert', 'url_emb_20',
#        'url_emb_21', 'url_emb_22', 'url_emb_23', 'url_emb_24',
#        'url_emb_25', 'url_emb_26', 'url_emb_27', 'url_emb_28',
#        'url_emb_29', 'url_emb_30', 'url_emb_31', 'url_emb_32',
#        'url_emb_33', 'url_emb_34', 'url_emb_35', 'url_emb_36',
#        'url_emb_37', 'url_emb_38', 'url_emb_39'], dtype=object)
